# %% [markdown]
# # Functions

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# -> Function
# A function is a block of reusable code that performs a specific task. Function use def keyword.
#
# Method
# A method is a function that is associated with an object (typically, an instance of a class). The method is uses dot notation (object.method()).
#
#
#
#
# 2. Second Question
#
# -> Parameter
# A parameter is the name you use when you define a function, it's like a blank space or placeholder.
# def greet(name):  # 'name' is a parameter
#     print("Hello", name)
#
# Argument
# An argument is the actual value you give when you call the function.
# greet("Alice")  # "Alice" is the argument
#
#
#
#
#
# 3. Third Question
#
# -> functions are defined using the def or lambda keywords and can be called in various ways.
#  Defining a Function Using
#  def greet():
#     print("Hello!")
#
# Function with Parameters
#  def greet(name):
#     print("Hello,", name)
# greet("Deepankar")
#
# Function with Default Parameters
# def greet(name="Guest"):
#     print("Hello,", name)
# greet()           # Hello, Guest
# greet("Deepankar")  # Hello, Deepankar
#
# Function with Return Statement
# def add(a, b):
#     return a + b
# result = add(5, 3)
# print(result)  # 8
#
# Lambda Function (Anonymous Function)
# square = lambda x: x * x
# print(square(5))  # 25
#
#  Function with Variable Number of Arguments
# def print_all(*args):
#     for item in args:
#         print(item)
# print_all(1, 2, 3, 4
#
#  Recursive Function (Function calling itself)
# def factorial(n):
#     if n == 0:
#     return n * factorial(n - 1)
#
# Function as Argument (Higher-order functions)
# def apply(func, value):
#     return func(value)
# print(apply(double, 4))  # 8
#
# Function inside another function (Nested Functions)
# def outer():
# def inner():
# print("Inside inner function")
#
#
#
#
#
# 4. Fourth Question
# -> The return statement in a Python function is used to send a value back to the place where the function was called. It marks the end of the function's execution and optionally provides a result.
#
#
#
#
#
# 5. Fifth Question
#
# -> Iterable
# An iterable is any Python object capable of returning its members one at a time, allowing it to be looped over (e.g., in a for loop).
#
# Iterator
# An iterator is an object that represents a stream of data; it remembers its current position while iterating.
#
#
#
#
# 6. Sixth Question
#
# A generator is a special type of iterator in Python that is used to generate values on the fly and is more memory-efficient than storing them all at once.
#
#
#
#
# 7. Seventh Queston
#
# Using generators in Python offers several advantages over regular functions (especially those that return lists or other collections). Here’s a breakdown of the key benefits:
# I. Memory Efficiency (Low Memory Usage)
# II. Lazy Evaluation
# III. Improved Performance (Faster Start Time)
#
#
#
#
# 8. Eight Queston
#
# -> A lambda function in Python is a small anonymous function defined using the lambda keyword. It can take any number of arguments, but has only one expression.
#
#
#
# 9. Nineth Question
#
# ->The map() function in Python is used to apply a function to every item in an iterable (like a list, tuple, etc.) and return a new iterator with the results.
#
#
#
#
# 10. Tenth Question
#
# ->  map(function, iterable)
#
# Applies a function to each item of the iterable and returns a new iterator with the results.
# numbers = [1, 2, 3, 4]
# squared = list(map(lambda x: x**2, numbers))
# # Output: [1, 4, 9, 16]
#
# filter(function, iterable)
#
# Filters the iterable, returning only items for which the function returns True.
# numbers = [1, 2, 3, 4, 5, 6]
# even = list(filter(lambda x: x % 2 == 0, numbers))
# # Output: [2, 4, 6]
#
# reduce(function, iterable)
# Applies a function cumulatively to the items of the iterable, reducing it to a single value.
# from functools import reduce
# numbers = [1, 2, 3, 4]
# total = reduce(lambda x, y: x + y, numbers)
# # Output: 10
#
#
#
#
# 11. Eleventh Question
#
# Image('your_image.png')
# -> Please check answeer given in pdf.

# %%
# Theory Question Eleventh

from google.colab import files
from IPython.display import Image

# Upload the image
uploaded = files.upload()

# Display the image
Image('your_image.png')
# Out:
#      <input type="file" id="files-fed67a37-20b9-440b-8819-b5ea839e8884" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fed67a37-20b9-440b-8819-b5ea839e8884">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 1. First Question

def sum_even_numbers(numbers):
    even_sum = 0
    for num in numbers:
        if num % 2 == 0:
            even_sum += num
    return eve
  n_sum




# 2. Second Question

def reverse_string(text):
    return text[::-1]




# 3. Third Question

nums = [1, 2, 3, 4, 5]




#4. Fourth Question

def is_prime(n):
    if n <= 1:
        return False  # 0 and 1 are not prime
    if n == 2:
        return True   # 2 is the only even prime
    if n % 2 == 0:
        return False  # Exclude other even numbers

    for i in range(3, int(n**0.5) + 1, 2):
        if n % i == 0:
            return False
    return True




    #5. Fifth Question

class Fibonacci:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return self.a
        elif self.count == 1:
            self.count += 1
            return self.b
        else:
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return self.b

#6. Sixth Question

def powers_of_two(n):
    for i in range(n + 1):
        yield 2 ** i




#7. Seventh Question

def read_file_line_by_line(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()  # .strip() removes leading/trailing whitespace including \n






#8. Eight Question

data = [(1, 'banana'), (3, 'apple'), (2, 'cherry')]

# Sort by second element (index 1) using lambda
sorted_data = sorted(data, key=lambda x: x[1])

print(sorted_data)




#9. Nineth Question

# List of temperatures in Celsius
celsius_temps = [0, 20, 30, 37, 100]

# Use map() with lambda to convert to Fahrenheit
fahrenheit_temps = list(map(lambda c: (c * 9/5) + 32, celsius_temps))

# Print the results
print("Celsius:", celsius_temps)
print("Fahrenheit:", fahrenheit_temps)




#10. Tenth Question

def remove_vowels(text):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda char: char not in vowels, text))

# Example usage
input_str = "Deepankar"
result = remove_vowels(input_str)

print("Original string:", input_str)
print("Without vowels:", result)





#11. Eleventh Question

# List of orders: [order number, book title and author, quantity, price per item]
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einfuhrung in Python3, Bernd Klein", 3, 24.99]
]

# Use map and lambda to compute (order number, total price), with €10 added if total < 100
invoice = list(map(lambda order: (
    order[0],
    round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)
), orders))

# Print result
print(invoice)
# Out:
# [(3, 'apple'), (1, 'banana'), (2, 'cherry')]
# Celsius: [0, 20, 30, 37, 100]
# Fahrenheit: [32.0, 68.0, 86.0, 98.6, 212.0]
# Original string: Deepankar
# Without vowels: Dpnkr
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
